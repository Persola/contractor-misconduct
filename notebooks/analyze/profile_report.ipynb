# %%
import pickle
import pandas_profiling

# %%
DATA_DIR = '../../data/clean/'

with open(f'{DATA_DIR}misconduct_indicators_train.pkl', 'rb') as train_file:
    indicated_misconduct = pickle.load(train_file)

# %%
with open(f'{DATA_DIR}misconduct_train.pkl', 'rb') as train_file:
    orig_misconduct = pickle.load(train_file)

pandas_profiling.ProfileReport(orig_misconduct)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...
